# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#Import excel 
data =pd.read_excel(r'D:\\Thambi\\Learning\\DataScience\\AssignmentfileforDataAnalyst.xlsx')
                    
#Check for null
data.isnull().sum()
          
#Read GridStatus,SOC,Equivalent cycle,SOH and Temperature
dfGridStatus=pd.DataFrame(data,columns=['Grid status'])
dfSOC=pd.DataFrame(data,columns =['SOC'])
dfEquivalentcycle=pd.DataFrame(data,columns =['Equivalent cycle'])
dfSOH=pd.DataFrame(data,columns=['SOH'])
dfTemperature=pd.DataFrame(data,columns=['Temperature'])

#Find correlation and plot heatmap
#Part 1
plt.figure(figsize = (6,5))                
correlationpart1 = data.corr()
correlation1 = data[["Grid status","SOC"]].corr()
sns.heatmap(correlation1,annot = True, cmap = plt.cm.Reds)


#Part 2
plt.figure(figsize = (6,5))
correlationpart2 = data.corr()
correlation2 = data[["Equivalent cycle","SOH"]].corr()
sns.heatmap(correlation2,annot = True, cmap = plt.cm.Reds)

#Part 3
plt.figure(figsize = (6,5))
correlationpart3 = data.corr()
correlation3 = data[["SOC","Temperature"]].corr()
sns.heatmap(correlation3,annot = True, cmap = plt.cm.Reds)
